# %%
telco_df = spark.read.table("telco_customer_churn")

display(telco_df)

# %%
# Select columns of interest
telco_df = telco_df.select("gender", "SeniorCitizen", "Partner", "tenure", "InternetService", "Contract", "PaperlessBilling", "PaymentMethod", "TotalCharges", "Churn")

# %% [markdown]
# ## Handling Null values

# %%
from pyspark.sql.functions import when, col, trim

for column in telco_df.columns:
    telco_df = telco_df.withColumn(column, when(trim(col(column)) == "", None).otherwise(col(column)))

# %%
display(telco_df)
